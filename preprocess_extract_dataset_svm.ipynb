# %% [markdown]
# # Preprocess and Feature Extraction - Flavia dataset
#
# Extracted features are saved in file named "Flavia_features.csv"

# %%
# !pip install mahotas
import os
import cv2
import numpy as np
import pandas as pd
import mahotas as mt
from matplotlib import pyplot as plt
from tqdm import tqdm
# %matplotlib inline

# %%
ds_path = "dataset\Leaves"
img_files = os.listdir(ds_path)
print(ds_path)
print('file number :',len(img_files))
# Out:
# dataset\Leaves
# file number : 1908

# %%
def create_dataset():
    names = ['area','perimeter','physiological_length','physiological_width','aspect_ratio','rectangularity','circularity', \
             'mean_r','mean_g','mean_b','stddev_r','stddev_g','stddev_b', \
             'contrast','correlation','inverse_difference_moments','entropy'
            ]
    df = pd.DataFrame([], columns=names)
    for file in tqdm(img_files):
        imgpath = ds_path +'\\'+ file

        main_img = cv2.imread(imgpath)
        
        #Preprocessing
        img = cv2.cvtColor(main_img, cv2.COLOR_BGR2RGB)
        gs = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
        

        blur = cv2.GaussianBlur(gs, (25,25),0)
        ret_otsu,im_bw_otsu = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
        kernel = np.ones((50,50),np.uint8)
        closing = cv2.morphologyEx(im_bw_otsu, cv2.MORPH_CLOSE, kernel)
        
        #Shape features
        contours, _ = cv2.findContours(closing,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
        cnt = contours[0]
        M = cv2.moments(cnt)
        area = cv2.contourArea(cnt)
        perimeter = cv2.arcLength(cnt,True)
        x,y,w,h = cv2.boundingRect(cnt)
        aspect_ratio = float(w)/h
        if area ==0:
            continue
        rectangularity = w*h/area
        circularity = ((perimeter)**2)/area
        
        #Color features
        red_channel = img[:,:,0]
        green_channel = img[:,:,1]
        blue_channel = img[:,:,2]
        blue_channel[blue_channel == 255] = 0
        green_channel[green_channel == 255] = 0
        red_channel[red_channel == 255] = 0
        
        red_mean = np.mean(red_channel)
        green_mean = np.mean(green_channel)
        blue_mean = np.mean(blue_channel)
        
        red_std = np.std(red_channel)
        green_std = np.std(green_channel)
        blue_std = np.std(blue_channel)
        
        #Texture features
        textures = mt.features.haralick(gs)
        ht_mean = textures.mean(axis=0)
        contrast = ht_mean[ 1]
        correlation = ht_mean[2]
        inverse_diff_moments = ht_mean[4]
        entropy = ht_mean[8]
        
        vector = [area,perimeter,w,h,aspect_ratio,rectangularity,circularity,\
                  red_mean,green_mean,blue_mean,red_std,green_std,blue_std,\
                  contrast,correlation,inverse_diff_moments,entropy
                 ]
        
        df_temp = pd.DataFrame([vector],columns=names)
        df = pd.concat([df,df_temp])
 
    return df

# %%
dataset = create_dataset()
dataset.to_csv("Flavia_features.csv")
# Out:
#   0%|                                                                                         | 0/1908 [00:00<?, ?it/s]C:\Users\vjosv\AppData\Local\Temp\ipykernel_33948\2460785280.py:65: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df_temp])
#   6%|████▉                                                                          | 120/1908 [00:11<02:47, 10.69it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 dataset = create_dataset()
#       2 dataset.to_csv("Flavia_features.csv")
#
# Cell In[20], line 52, in create_dataset()
#      49 blue_std = np.std(blue_channel)
#      51 #Texture features
# ---> 52 textures = mt.features.haralick(gs)
#      53 ht_mean = textures.mean(axis=0)
#      54 contrast = ht_mean[1]
#
# File ~\anaconda3\envs\cuda_env\Lib\site-packages\mahotas\features\texture.py:141, in haralick(f, ignore_zeros, preserve_haralick_bug, compute_14th_feature, return_mean, return_mean_ptp, use_x_minus_y_variance, distance)
#     139         cooccurence(f, dir, cmat, symmetric=True, distance=distance)
#     140         yield cmat
# --> 141 return haralick_features(all_cmatrices(),
#     142                     ignore_zeros=ignore_zeros,
#     143                     preserve_haralick_bug=preserve_haralick_bug,
#     144                     compute_14th_feature=compute_14th_feature,
#     145                     return_mean=return_mean,
#     146                     return_mean_ptp=return_mean_ptp,
#     147                     use_x_minus_y_variance=use_x_minus_y_variance,
#     148                     )
#
# File ~\anaconda3\envs\cuda_env\Lib\site-packages\mahotas\features\texture.py:313, in haralick_features(cmats, ignore_zeros, preserve_haralick_bug, compute_14th_feature, return_mean, return_mean_ptp, use_x_minus_y_variance)
#     310 else:
#     311     feats[6] = np.dot(tk2, px_plus_y) - feats[5]**2
# --> 313 feats[ 8] = _entropy(pravel)
#     314 if use_x_minus_y_variance:
#     315     mu_x_minus_y = np.dot(px_minus_y, k)
#
# File ~\anaconda3\envs\cuda_env\Lib\site-packages\mahotas\features\texture.py:21, in _entropy(p)
#      19 p1 = p.copy()
#      20 p1 += (p==0)
# ---> 21 return -np.dot(np.log2(p1), p)
#
# KeyboardInterrupt:

# %% [markdown]
# # Preprocess and Feature Extraction - Flavia dataset
#
# Extracted features are saved in file named "leaf_snap_features.csv"

# %%
ds_path = ""
# ds_path =''
# img_files = os.listdir(ds_path)
dat = pd.read_csv('leafsnap-dataset-train-images_224_svm.csv')
img_files = dat['image_paths'].to_list()
targets = dat['species'].to_list()
dat.head()
# Out:
#    Unnamed: 0                                       image_paths  \
# 0           0     dataset/train_224_svm/ptelea_trifoliata\1.jpg
# 1           1      dataset/train_224_svm/pinus_virginiana\2.jpg
# 2           2  dataset/train_224_svm/magnolia_grandiflora\3.jpg
# 3           3   dataset/train_224_svm/albizia_julibrissin\4.jpg
# 4           4       dataset/train_224_svm/salix_matsudana\5.jpg
#
#                 species
# 0     Ptelea trifoliata
# 1      Pinus virginiana
# 2  Magnolia grandiflora
# 3   Albizia julibrissin
# 4       Salix matsudana

# %%
def create_dataset():
    names = ['area','perimeter','physiological_length','physiological_width','aspect_ratio','rectangularity','circularity', \
             'mean_r','mean_g','mean_b','stddev_r','stddev_g','stddev_b', \
             'contrast','correlation','inverse_difference_moments','entropy'
            ]
    df = pd.DataFrame([], columns=names)
    for file in img_files:
        imgpath = ds_path + file

        main_img = cv2.imread(imgpath)
        
        #Preprocessing
        img = cv2.cvtColor(main_img, cv2.COLOR_BGR2RGB)
        gs = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
        blur = cv2.GaussianBlur(gs, (25,25),0)
        ret_otsu,im_bw_otsu = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
        kernel = np.ones((50,50),np.uint8)
        closing = cv2.morphologyEx(im_bw_otsu, cv2.MORPH_CLOSE, kernel)
        
        #Shape features
        contours, _ = cv2.findContours(closing,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
        cnt = contours[0]
        M = cv2.moments(cnt)
        area = cv2.contourArea(cnt)
        perimeter = cv2.arcLength(cnt,True)
        x,y,w,h = cv2.boundingRect(cnt)
        aspect_ratio = float(w)/h
        if area ==0:
            continue
        rectangularity = w*h/area
        circularity = ((perimeter)**2)/area
        
        #Color features
        red_channel = img[:,:,0]
        green_channel = img[:,:,1]
        blue_channel = img[:,:,2]
        blue_channel[blue_channel == 255] = 0
        green_channel[green_channel == 255] = 0
        red_channel[red_channel == 255] = 0
        
        red_mean = np.mean(red_channel)
        green_mean = np.mean(green_channel)
        blue_mean = np.mean(blue_channel)
        
        red_std = np.std(red_channel)
        green_std = np.std(green_channel)
        blue_std = np.std(blue_channel)
        
        #Texture features
        textures = mt.features.haralick(gs)
        ht_mean = textures.mean(axis=0)
        contrast = ht_mean[1]
        correlation = ht_mean[2]
        inverse_diff_moments = ht_mean[4]
        entropy = ht_mean[8]
        
        vector = [area,perimeter,w,h,aspect_ratio,rectangularity,circularity,\
                  red_mean,green_mean,blue_mean,red_std,green_std,blue_std,\
                  contrast,correlation,inverse_diff_moments,entropy
                 ]
        
        df_temp = pd.DataFrame([vector],columns=names)
        df = pd.concat([df,df_temp])
        print(file)
    return df

# %%
from tqdm import tqdm

# dataset = create_dataset()
names = ['area','perimeter','physiological_length','physiological_width','aspect_ratio','rectangularity','circularity', \
         'mean_r','mean_g','mean_b','stddev_r','stddev_g','stddev_b', \
         'contrast','correlation','inverse_difference_moments','entropy', 'target'
        ]
df = pd.DataFrame([], columns=names)
for file,target in tqdm(zip(img_files,targets)):
    imgpath = ds_path + file

    main_img = cv2.imread(imgpath)

    #Preprocessing
    img = cv2.cvtColor(main_img, cv2.COLOR_BGR2RGB)
    gs = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
    blur = cv2.GaussianBlur(gs, (25,25),0)
    ret_otsu,im_bw_otsu = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
    kernel = np.ones((50,50),np.uint8)
    closing = cv2.morphologyEx(im_bw_otsu, cv2.MORPH_CLOSE, kernel)

    #Shape features
    contours, _ = cv2.findContours(closing,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    try:
        cnt = contours[0]
    except:
        continue
    M = cv2.moments(cnt)
    area = cv2.contourArea(cnt)
    perimeter = cv2.arcLength(cnt,True)
    x,y,w,h = cv2.boundingRect(cnt)
    aspect_ratio = float(w)/h
    if area ==0:
        continue
    rectangularity = w*h/area
    circularity = ((perimeter)**2)/area

    #Color features
    red_channel = img[:,:,0]
    green_channel = img[:,:,1]
    blue_channel = img[:,:,2]
    blue_channel[blue_channel == 255] = 0
    green_channel[green_channel == 255] = 0
    red_channel[red_channel == 255] = 0

    red_mean = np.mean(red_channel)
    green_mean = np.mean(green_channel)
    blue_mean = np.mean(blue_channel)

    red_std = np.std(red_channel)
    green_std = np.std(green_channel)
    blue_std = np.std(blue_channel)

    #Texture features
    textures = mt.features.haralick(gs)
    ht_mean = textures.mean(axis=0)
    contrast = ht_mean[1]
    correlation = ht_mean[2]
    inverse_diff_moments = ht_mean[4]
    entropy = ht_mean[8]

    vector = [area,perimeter,w,h,aspect_ratio,rectangularity,circularity,\
              red_mean,green_mean,blue_mean,red_std,green_std,blue_std,\
              contrast,correlation,inverse_diff_moments,entropy,target
             ]

    df_temp = pd.DataFrame([vector],columns=names)
    df = pd.concat([df,df_temp])
    # print(file)
# Out:
# 0it [00:00, ?it/s]C:\Users\vjosv\AppData\Local\Temp\ipykernel_33948\87464084.py:68: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df,df_temp])
# 334it [00:03, 103.98it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 68
#      62 vector = [area,perimeter,w,h,aspect_ratio,rectangularity,circularity,\
#      63           red_mean,green_mean,blue_mean,red_std,green_std,blue_std,\
#      64           contrast,correlation,inverse_diff_moments,entropy,target
#      65          ]
#      67 df_temp = pd.DataFrame([vector],columns=names)
# ---> 68 df = pd.concat([df,df_temp])
#
# File ~\anaconda3\envs\cuda_env\Lib\site-packages\pandas\core\reshape\concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File ~\anaconda3\envs\cuda_env\Lib\site-packages\pandas\core\reshape\concat.py:680, in _Concatenator.get_result(self)
#     676             indexers[ax] = obj_labels.get_indexer(new_labels)
#     678     mgrs_indexers.append((obj._mgr, indexers))
# --> 680 new_data = concatenate_managers(
#     681     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     682 )
#     683 if not self.copy and not using_copy_on_write():
#     684     new_data._consolidate_inplace()
#
# File ~\anaconda3\envs\cuda_env\Lib\site-packages\pandas\core\internals\concat.py:177, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     167 vals = [ju.block.values for ju in join_units]
#     169 if not blk.is_extension:
#     170     # _is_uniform_join_units ensures a single dtype, so
#     171     #  we can use np.concatenate, which is more performant
#    (...)
#     175     # expected "Union[_SupportsArray[dtype[Any]],
#     176     # _NestedSequence[_SupportsArray[dtype[Any]]]]"
# --> 177     values = np.concatenate(vals, axis=1)  # type: ignore[arg-type]
#     178 elif is_1d_only_ea_dtype(blk.dtype):
#     179     # TODO(EA2D): special-casing not needed with 2D EAs
#     180     values = concat_compat(vals, axis=0, ea_compat_axis=True)
#
# KeyboardInterrupt:

# %%
dataset = df

dataset.to_csv("leaf_snap_features.csv")

# %%
dataset.shape
# Out:
# (23585, 18)

# %%
# Out:
# pandas.core.frame.DataFrame

# %%
# Out:
# 485129.5

# %%
# Out:
#       Unnamed: 0      area    perimeter  physiological_length  \
# 0              0  485129.5  3822.131487                  1459
# 1              0  489890.0  3809.143686                  1422
# 2              0  307903.5  2569.731221                  1114
# 3              0  245870.5  2813.824586                  1264
# 4              0   69526.5  3704.076776                  1448
# ...          ...       ...          ...                   ...
# 1902           0  461140.0  6378.520442                  1274
# 1903           0  637829.5  4121.739572                  1191
# 1904           0  371950.5  3847.376212                  1460
# 1905           0  764912.5  4271.960790                  1141
# 1906           0  819971.0  4030.075579                  1446
#
#       physiological_width  aspect_ratio  rectangularity  circularity  \
# 0                     905      1.612155        2.721737    30.112968
# 1                     945      1.504762        2.743044    29.618028
# 2                     394      2.827411        1.425499    21.446715
# 3                     327      3.865443        1.681080    32.202354
# 4                     964      1.502075       20.076834   197.337487
# ...                   ...           ...             ...          ...
# 1902                 1101      1.157130        3.041753    88.228137
# 1903                 1055      1.128910        1.969970    26.635233
# 1904                  967      1.509824        3.795720    39.796435
# 1905                 1014      1.125247        1.512557    23.858479
# 1906                  932      1.551502        1.643561    19.807419
#
#           mean_r      mean_g      mean_b   stddev_r   stddev_g    stddev_b  \
# 0      21.548321   38.921378   10.541783  41.316764  67.891852   26.448052
# 1      11.758990   50.206020    2.000756  25.948078  84.915973   17.924460
# 2      10.248443   19.695162   16.331825  45.721887  48.443413   60.486853
# 3      14.705938   20.883349   13.306845  40.661030  52.649291   38.531062
# 4       7.405359    9.433330    5.798306  34.457877  43.523617   30.145214
# ...          ...         ...         ...        ...        ...         ...
# 1902   23.783565   36.293105   21.694625  45.075537  64.668263   41.827096
# 1903   28.881916   46.498822   23.016589  44.130072  65.783191   37.395361
# 1904   18.641599   34.809681    9.775415  40.488711  69.770100   26.659364
# 1905   34.912162   54.138055   26.549748  45.961112  66.759222   37.250674
# 1906  171.984938  198.824353  160.593156  95.747323  64.531587  106.615784
#
#        contrast  correlation  inverse_difference_moments   entropy
# 0     55.779676     0.992673                    0.774745  4.046708
# 1     12.757222     0.998075                    0.810892  3.549434
# 2      8.076081     0.999279                    0.860258  2.823292
# 3      4.589367     0.999007                    0.899268  2.009211
# 4      1.927087     0.997009                    0.960461  0.865603
# ...         ...          ...                         ...       ...
# 1902  28.238168     0.995964                    0.795875  3.599582
# 1903  26.604019     0.997254                    0.716242  4.674605
# 1904  21.478996     0.995827                    0.825369  3.049712
# 1905  23.082022     0.997802                    0.678819  5.431301
# 1906  66.625043     0.994589                    0.607550  6.629738
#
# [1907 rows x 18 columns]

# %%
# Out:
# 1907
